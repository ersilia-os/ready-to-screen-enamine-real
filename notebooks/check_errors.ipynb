# %%
from tqdm import tqdm
import os

# %%
path = "/aloy/scratch/acomajuncosa/Ersilia/ready-to-screen-enamine-real"
for file in tqdm(sorted(os.listdir(path))):
    lines = open(os.path.join(path, file)).readlines()
    error_lines = [i for i in lines if "error" in i.lower() or "warning" in i.lower()]
    if len(error_lines) > 0:
        print(file)
# Out:
# 100%|██████████| 994/994 [09:07<00:00,  1.82it/s]

# %%
path = "/aloy/scratch/acomajuncosa/Ersilia/ready-to-screen-enamine-real_rerun"
for file in tqdm(sorted(os.listdir(path))):
    lines = open(os.path.join(path, file)).readlines()
    error_lines = [i for i in lines if "error" in i.lower() or "warning" in i.lower()]
    if len(error_lines) > 0:
        print(file)
# Out:
#  99%|█████████▉| 89/90 [01:00<00:00,  2.68it/s]
# enamine-real--ecfp_88.out
# enamine-real--ecfp_89.out
# 100%|██████████| 90/90 [01:00<00:00,  1.48it/s]
